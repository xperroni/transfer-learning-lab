# %%
from cifar10_baseline import main


main()
# Out:
#   --------------------------------------------------------------------------------
#   Train dataset (total 50000 entries)
#   --------------------------------------------------------------------------------
#
#
#   Class 0 ("airplane", total 5000 entries) samples:
#   Class 1 ("automobile", total 5000 entries) samples:
#   Class 2 ("bird", total 5000 entries) samples:
#   Class 3 ("cat", total 5000 entries) samples:
#   Class 4 ("deer", total 5000 entries) samples:
#   Class 5 ("dog", total 5000 entries) samples:
#   Class 6 ("frog", total 5000 entries) samples:
#   Class 7 ("horse", total 5000 entries) samples:
#   Class 8 ("ship", total 5000 entries) samples:
#   Class 9 ("truck", total 5000 entries) samples:
# Epoch  1/5:  31%|███       | 229/750 [07:38<07:47,  1.12batches/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-baa9d29dc5a9> in <module>()
# ...
